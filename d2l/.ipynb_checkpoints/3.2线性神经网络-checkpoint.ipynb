# %%
# 3.2 线性回归从0开始实现

# %%
import torch
import random
import matplotlib.pyplot as plt

# %%
def synthetic_data(w,b,num_examples):  #@save
    "生成y=Xw+b+噪声"
    X = torch.normal(0,1,(num_examples,len(w)))
    y = torch.matmul(X,w)+b
    y += torch.normal(0,0.01,y.shape)
    return X,y.reshape((-1,1))

# %%
true_w = torch.tensor([2,-3.4])
true_b = 4.2
features,labels = synthetic_data(true_w,true_b,1000)

# %%
features[0],labels[0]
# Out:
# (tensor([0.4249, 0.1933]), tensor([4.4007]))

# %%
plt.scatter(features[:,1].detach().numpy(),labels.detach().numpy())

# %%
def data_iter(batch_size,features,labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    # 这些样本是随机读取的，没有特定的顺序
    random.shuffle(indices)
    for i in range(0,num_examples,batch_size):
        batch_indices = torch.tensor(indices[i:min(i+batch_size,num_examples)])
        yield features[batch_indices],labels[batch_indices]

# %%
batch_size = 10
for X,y in data_iter(batch_size,features,labels):
    print(X,'\n',y)
    break
# Out:
# tensor([[ 0.1902,  0.7712],
#         [ 0.6026,  1.0941],
#         [ 0.6188,  0.6638],
#         [ 1.6722,  0.2788],
#         [-2.7898, -0.3692],
#         [ 0.1836, -1.3947],
#         [ 0.4650,  0.7022],
#         [-0.4264,  0.9608],
#         [ 2.0414,  0.1550],
#         [-0.8378, -0.5089]])
#  tensor([[ 1.9681],
#         [ 1.6873],
#         [ 3.1756],
#         [ 6.6001],
#         [-0.1324],
#         [ 9.3183],
#         [ 2.7274],
#         [ 0.1097],
#         [ 7.7644],
#         [ 4.2653]])

# %%
batch_size = 10
for X,y in data_iter(batch_size,features,labels):
    print(X,'\n',y)
    break
# Out:
# tensor([[ 0.4607, -0.2089],
#         [-2.1296,  1.0961],
#         [ 0.3607,  0.4933],
#         [ 0.1017,  0.9622],
#         [ 0.2415, -1.1155],
#         [ 0.6331, -0.7177],
#         [ 0.1356,  0.5579],
#         [-0.5262,  1.3694],
#         [-0.0167,  1.5493],
#         [-0.3526,  1.1483]])
#  tensor([[ 5.8420],
#         [-3.7874],
#         [ 3.2660],
#         [ 1.1235],
#         [ 8.4738],
#         [ 7.9092],
#         [ 2.5715],
#         [-1.4983],
#         [-1.1047],
#         [-0.4018]])

# %%
w = torch.normal(0,0.01,size=(2,1),requires_grad = True)
b = torch.zeros(1,requires_grad = True)

def linreg(X,w,b):
    """线性回归模型"""
    return torch.matmul(X,w)+b

def squared_loss(y_hat,y):
    """平方损失"""
    return (y_hat-y)**2/2

def sgd(params,lr,batch_size):
    """小批量随机梯度下降"""
    with torch.no_grad():
        for param in params:
            param -= lr * param.grad/batch_size
            param.grad.zero_()

lr = 0.03
num_epochs = 3
net = linreg
loss = squared_loss

for epoch in range(num_epochs):
    for X,y in data_iter(batch_size,features,labels):
        l = loss(net(X,w,b),y)
        l.sum().backward()
        sgd([w,b],lr,batch_size)
    with torch.no_grad():
        train_l = loss(net(features,w,b),labels)
        print(f'epoch {epoch+1}, loss {float(train_l.mean()):f}')
# Out:
# epoch 1, loss 0.030941
# epoch 2, loss 0.000111
# epoch 3, loss 0.000048

# %%
# 3.3 线性回归的简洁实现

# %%
import numpy as np
from torch.utils import data

# %%
true_w = torch.tensor([2,-3.4])
true_b = 4.2
features,labels = synthetic_data(true_w,true_b,1000)

# %%
def load_array(data_arrays,batch_size,is_train=True):
    """构造一个Pytorch数据迭代器"""
    dataset = data.TensorDataset(*data_arrays)
    return data.DataLoader(dataset,batch_size,shuffle = is_train)

# %%
batch_size = 10
data_iter = load_array((features,labels),batch_size)
data_iter,iter(data_iter)
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x286f446eb70>,
#  <torch.utils.data.dataloader._SingleProcessDataLoaderIter at 0x286f4566390>)

# %%
dataset = data.TensorDataset(features, labels)
data_iter = data.DataLoader(dataset, batch_size, shuffle=True)
dataset

# %%
from torch import nn
net = nn.Sequential(nn.Linear(2,1))
net[0].weight.data,net[0].bias.data
# Out:
# (tensor([[ 0.2407, -0.1984]]), tensor([0.1272]))

# %%
net[0].weight.data.normal_(0,0.01),net[0].bias.data.fill_(0)
# Out:
# (tensor([[-0.0022,  0.0027]]), tensor([0.]))

# %%
loss = nn.MSELoss()
trainer = torch.optim.SGD(net.parameters(),lr=0.03)

# %%
num_epochs = 3
for epoch in range(num_epochs):
    for X,y in data_iter:
        l = loss(net(X),y)
        trainer.zero_grad()
        l.backward()
        print(net[0].weight.grad)
        trainer.step()
    l = loss(net(features),labels)
    print(f'epoch {epoch+1},loss {l:f}')
# Out:
# tensor([[-0.0028,  0.0017]])
# tensor([[0.0065, 0.0127]])
# tensor([[-0.0052,  0.0055]])
# tensor([[-0.0016, -0.0029]])
# tensor([[-0.0049, -0.0025]])
# tensor([[0.0093, 0.0097]])
# tensor([[-0.0084, -0.0049]])
# tensor([[-0.0048, -0.0020]])
# tensor([[3.2593e-03, 7.5470e-05]])
# tensor([[-0.0112, -0.0086]])
# tensor([[-0.0071,  0.0006]])
# tensor([[ 0.0132, -0.0023]])
# tensor([[-0.0037, -0.0081]])
# tensor([[-0.0075, -0.0021]])
# tensor([[0.0189, 0.0073]])
# tensor([[1.5291e-02, 3.8279e-05]])
# tensor([[ 0.0044, -0.0076]])
# tensor([[-0.0036,  0.0016]])
# tensor([[-0.0112, -0.0003]])
# tensor([[ 0.0042, -0.0092]])
# tensor([[-0.0132, -0.0002]])
# tensor([[-0.0014,  0.0029]])
# tensor([[ 0.0071, -0.0065]])
# tensor([[-0.0115, -0.0056]])
# tensor([[-0.0034, -0.0127]])
# tensor([[-0.0021, -0.0004]])
# tensor([[-0.0030,  0.0028]])
# tensor([[ 0.0034, -0.0095]])
# tensor([[-4.0879e-05,  7.8089e-03]])
# tensor([[-0.0067,  0.0118]])
# tensor([[0.0084, 0.0101]])
# tensor([[0.0072, 0.0030]])
# tensor([[-0.0006, -0.0016]])
# tensor([[-0.0024, -0.0049]])
# tensor([[-0.0030, -0.0034]])
# tensor([[-5.4194e-04, -4.8333e-05]])
# tensor([[0.0064, 0.0006]])
# tensor([[-0.0032,  0.0110]])
# tensor([[-0.0011, -0.0050]])
# tensor([[0.0146, 0.0017]])
# tensor([[0.0030, 0.0099]])
# tensor([[ 0.0096, -0.0025]])
# tensor([[0.0069, 0.0011]])
# tensor([[-2.3700e-03,  3.4749e-05]])
# tensor([[0.0014, 0.0009]])
# tensor([[-0.0035, -0.0057]])
# tensor([[-0.0041,  0.0007]])
# tensor([[ 0.0024, -0.0096]])
# tensor([[-0.0020,  0.0057]])
# tensor([[-0.0029, -0.0056]])
# tensor([[-0.0033,  0.0067]])
# tensor([[0.0007, 0.0010]])
# tensor([[0.0125, 0.0069]])
# tensor([[0.0130, 0.0107]])
# tensor([[ 0.0230, -0.0032]])
# tensor([[-0.0028, -0.0077]])
# tensor([[-0.0074,  0.0013]])
# tensor([[0.0044, 0.0076]])
# tensor([[-0.0092, -0.0084]])
# tensor([[ 0.0146, -0.0032]])
# tensor([[-0.0003,  0.0052]])
# tensor([[-0.0030, -0.0051]])
# tensor([[-0.0094,  0.0101]])
# tensor([[-0.0102, -0.0025]])
# tensor([[-0.0123, -0.0053]])
# tensor([[-0.0028,  0.0042]])
# tensor([[-0.0017, -0.0087]])
# tensor([[-0.0004,  0.0088]])
# tensor([[-0.0096, -0.0070]])
# tensor([[0.0059, 0.0036]])
# tensor([[-0.0053, -0.0057]])
# tensor([[-0.0063,  0.0006]])
# tensor([[ 0.0035, -0.0042]])
# tensor([[-0.0055, -0.0003]])
# tensor([[-0.0055, -0.0038]])
# tensor([[ 0.0041, -0.0023]])
# tensor([[-0.0056,  0.0039]])
# tensor([[0.0020, 0.0031]])
# tensor([[-0.0032,  0.0009]])
# tensor([[0.0102, 0.0065]])
# tensor([[ 0.0027, -0.0066]])
# tensor([[ 0.0058, -0.0008]])
# tensor([[0.0034, 0.0018]])
# tensor([[-0.0115, -0.0109]])
# tensor([[-0.0043, -0.0035]])
# tensor([[ 0.0053, -0.0057]])
# tensor([[-0.0083,  0.0076]])
# tensor([[0.0035, 0.0053]])
# tensor([[-0.0041, -0.0082]])
# tensor([[-0.0069, -0.0141]])
# tensor([[0.0044, 0.0071]])
# tensor([[0.0008, 0.0028]])
# tensor([[ 0.0012, -0.0091]])
# tensor([[ 0.0038, -0.0049]])
# tensor([[0.0097, 0.0320]])
# tensor([[0.0048, 0.0081]])
# tensor([[0.0077, 0.0088]])
# tensor([[ 0.0073, -0.0068]])
# tensor([[-0.0082,  0.0001]])
# tensor([[0.0039, 0.0101]])
# epoch 1,loss 0.000095
# tensor([[-0.0001,  0.0052]])
# tensor([[0.0034, 0.0033]])
# tensor([[-0.0069, -0.0053]])
# tensor([[0.0069, 0.0029]])
# tensor([[-0.0046, -0.0049]])
# tensor([[ 0.0019, -0.0052]])
# tensor([[0.0041, 0.0009]])
# tensor([[0.0031, 0.0046]])
# tensor([[-0.0008,  0.0012]])
# tensor([[-0.0013,  0.0013]])
# tensor([[-0.0030, -0.0103]])
# tensor([[-0.0003, -0.0013]])
# tensor([[ 0.0076, -0.0023]])
# tensor([[-0.0111, -0.0086]])
# tensor([[-0.0013,  0.0030]])
# tensor([[-0.0110, -0.0098]])
# tensor([[-0.0083,  0.0004]])
# tensor([[-0.0030, -0.0023]])
# tensor([[0.0002, 0.0009]])
# tensor([[ 0.0102, -0.0020]])
# tensor([[-0.0027,  0.0112]])
# tensor([[ 0.0037, -0.0053]])
# tensor([[-0.0138, -0.0102]])
# tensor([[0.0004, 0.0105]])
# tensor([[ 0.0028, -0.0010]])
# tensor([[0.0032, 0.0065]])
# tensor([[-0.0147,  0.0055]])
# tensor([[0.0028, 0.0020]])
# tensor([[ 0.0073, -0.0097]])
# tensor([[ 0.0043, -0.0066]])
# tensor([[-0.0020, -0.0004]])
# tensor([[-0.0015, -0.0021]])
# tensor([[-0.0081, -0.0048]])
# tensor([[-0.0004, -0.0004]])
# tensor([[-0.0005,  0.0109]])
# tensor([[0.0070, 0.0002]])
# tensor([[-0.0060, -0.0037]])
# tensor([[ 0.0089, -0.0028]])
# tensor([[3.1170e-06, 2.2575e-03]])
# tensor([[7.6470e-05, 5.6283e-03]])
# tensor([[0.0029, 0.0050]])
# tensor([[ 0.0069, -0.0009]])
# tensor([[0.0025, 0.0106]])
# tensor([[-0.0017, -0.0071]])
# tensor([[ 0.0011, -0.0021]])
# tensor([[-0.0066, -0.0105]])
# tensor([[-0.0004, -0.0073]])
# tensor([[-0.0007,  0.0016]])
# tensor([[0.0035, 0.0006]])
# tensor([[0.0019, 0.0046]])
# tensor([[-0.0025, -0.0059]])
# tensor([[0.0044, 0.0043]])
# tensor([[0.0036, 0.0074]])
# tensor([[-0.0034,  0.0089]])
# tensor([[-0.0021,  0.0077]])
# tensor([[-0.0010,  0.0023]])
# tensor([[-0.0005, -0.0107]])
# tensor([[0.0032, 0.0072]])
# tensor([[0.0061, 0.0098]])
# tensor([[ 0.0035, -0.0078]])
# tensor([[ 0.0116, -0.0025]])
# tensor([[-0.0048, -0.0033]])
# tensor([[-0.0125,  0.0032]])
# tensor([[-0.0064,  0.0130]])
# tensor([[ 0.0034, -0.0015]])
# tensor([[0.0046, 0.0082]])
# tensor([[ 0.0010, -0.0120]])
# tensor([[-0.0041, -0.0022]])
# tensor([[ 0.0071, -0.0012]])
# tensor([[-0.0059, -0.0151]])
# tensor([[ 0.0005, -0.0065]])
# tensor([[0.0078, 0.0149]])
# tensor([[ 0.0025, -0.0049]])
# tensor([[-0.0103, -0.0075]])
# tensor([[ 0.0040, -0.0030]])
# tensor([[ 0.0057, -0.0068]])
# tensor([[0.0026, 0.0044]])
# tensor([[ 0.0021, -0.0084]])
# tensor([[-0.0063,  0.0084]])
# tensor([[-0.0074, -0.0010]])
# tensor([[-0.0048,  0.0074]])
# tensor([[0.0028, 0.0025]])
# tensor([[0.0165, 0.0024]])
# tensor([[ 9.6907e-05, -3.9281e-03]])
# tensor([[-0.0017, -0.0020]])
# tensor([[ 0.0018, -0.0025]])
# tensor([[-1.5278e-05, -4.4304e-03]])
# tensor([[0.0049, 0.0067]])
# tensor([[-0.0030,  0.0102]])
# tensor([[0.0101, 0.0051]])
# tensor([[-0.0106, -0.0002]])
# tensor([[-0.0122,  0.0110]])
# tensor([[ 0.0097, -0.0101]])
# tensor([[-0.0120, -0.0082]])
# tensor([[-0.0086, -0.0052]])
# tensor([[-0.0031,  0.0024]])
# tensor([[0.0013, 0.0033]])
# tensor([[-0.0070,  0.0063]])
# tensor([[-0.0002,  0.0011]])
# tensor([[ 3.4631e-05, -6.3921e-03]])
# epoch 2,loss 0.000094
# tensor([[ 0.0102, -0.0009]])
# tensor([[0.0051, 0.0041]])
# tensor([[-0.0076, -0.0023]])
# tensor([[-0.0090, -0.0019]])
# tensor([[ 0.0022, -0.0043]])
# tensor([[ 0.0046, -0.0050]])
# tensor([[-0.0049, -0.0015]])
# tensor([[-0.0073,  0.0047]])
# tensor([[0.0053, 0.0037]])
# tensor([[ 0.0127, -0.0076]])
# tensor([[-0.0072, -0.0032]])
# tensor([[0.0015, 0.0047]])
# tensor([[0.0006, 0.0068]])
# tensor([[-0.0027, -0.0100]])
# tensor([[-0.0114,  0.0013]])
# tensor([[0.0076, 0.0111]])
# tensor([[0.0053, 0.0023]])
# tensor([[0.0032, 0.0009]])
# tensor([[-0.0013,  0.0020]])
# tensor([[-0.0026,  0.0083]])
# tensor([[-0.0015,  0.0122]])
# tensor([[ 0.0081, -0.0117]])
# tensor([[0.0021, 0.0074]])
# tensor([[0.0095, 0.0085]])
# tensor([[ 0.0008, -0.0229]])
# tensor([[-0.0015, -0.0047]])
# tensor([[-0.0090,  0.0030]])
# tensor([[-0.0039, -0.0041]])
# tensor([[-1.8722e-05, -6.2854e-04]])
# tensor([[0.0092, 0.0015]])
# tensor([[-0.0035,  0.0033]])
# tensor([[-0.0081,  0.0084]])
# tensor([[-0.0070, -0.0089]])
# tensor([[-0.0043, -0.0019]])
# tensor([[-0.0003, -0.0037]])
# tensor([[ 0.0018, -0.0019]])
# tensor([[-0.0067,  0.0007]])
# tensor([[ 0.0013, -0.0073]])
# tensor([[ 0.0099, -0.0022]])
# tensor([[ 0.0010, -0.0100]])
# tensor([[-0.0021,  0.0008]])
# tensor([[0.0076, 0.0088]])
# tensor([[-0.0046, -0.0029]])
# tensor([[ 0.0020, -0.0051]])
# tensor([[0.0012, 0.0060]])
# tensor([[0.0065, 0.0032]])
# tensor([[-0.0049, -0.0069]])
# tensor([[-0.0042,  0.0046]])
# tensor([[ 0.0056, -0.0176]])
# tensor([[2.9116e-05, 8.3604e-03]])
# tensor([[0.0001, 0.0055]])
# tensor([[ 0.0076, -0.0053]])
# tensor([[ 0.0068, -0.0066]])
# tensor([[8.5034e-05, 3.5453e-03]])
# tensor([[-0.0006, -0.0003]])
# tensor([[-0.0022,  0.0049]])
# tensor([[-0.0078,  0.0064]])
# tensor([[ 0.0045, -0.0076]])
# tensor([[0.0038, 0.0094]])
# tensor([[-0.0122,  0.0084]])
# tensor([[ 0.0098, -0.0046]])
# tensor([[-0.0007,  0.0029]])
# tensor([[ 0.0061, -0.0029]])
# tensor([[-0.0078,  0.0020]])
# tensor([[ 0.0003, -0.0033]])
# tensor([[-0.0021,  0.0003]])
# tensor([[0.0070, 0.0085]])
# tensor([[0.0056, 0.0025]])
# tensor([[0.0011, 0.0011]])
# tensor([[-0.0010, -0.0008]])
# tensor([[-0.0017, -0.0055]])
# tensor([[0.0014, 0.0042]])
# tensor([[-0.0032, -0.0008]])
# tensor([[0.0060, 0.0075]])
# tensor([[ 0.0039, -0.0073]])
# tensor([[-4.8530e-03,  6.7484e-06]])
# tensor([[0.0067, 0.0080]])
# tensor([[0.0036, 0.0020]])
# tensor([[-0.0056, -0.0014]])
# tensor([[ 0.0067, -0.0029]])
# tensor([[-0.0065,  0.0074]])
# tensor([[ 0.0020, -0.0002]])
# tensor([[-0.0021, -0.0054]])
# tensor([[0.0027, 0.0026]])
# tensor([[ 0.0043, -0.0139]])
# tensor([[-0.0040, -0.0022]])
# tensor([[-0.0048, -0.0039]])
# tensor([[0.0026, 0.0023]])
# tensor([[-0.0080, -0.0004]])
# tensor([[-0.0025, -0.0076]])
# tensor([[-0.0038,  0.0046]])
# tensor([[-8.6801e-03, -6.1584e-05]])
# tensor([[-0.0008,  0.0023]])
# tensor([[ 0.0017, -0.0061]])
# tensor([[-0.0113,  0.0038]])
# tensor([[-0.0113,  0.0035]])
# tensor([[0.0113, 0.0017]])
# tensor([[-0.0140,  0.0049]])
# tensor([[-0.0045, -0.0100]])
# tensor([[ 0.0071, -0.0019]])
# epoch 3,loss 0.000096
