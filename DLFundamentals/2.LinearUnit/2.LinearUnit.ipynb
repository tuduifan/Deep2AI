# %%
# %run ./1.perceptron.ipynb

f = lambda x:x
class LinearUnit(Perceptron):
    def __init__(self,input_num):
        Perceptron.__init__(self,input_num,f)
# Out:
# weights	:[0.1, 0.2]
# bias	:-0.200000
#
# 1 and 1 = 1
# 0 and 0 = 0
# 1 and 0 = 0
# 0 and 1 = 0

# %%
def get_training_datasets():
    input_vecs = [[5],[3],[8],[1.4],[10.1]]
    labels = [5500,2300,7600,1800,11400]
    return input_vecs,labels

def train_linear_unit():
    lu = LinearUnit(1) #创建感知器
    input_vecs,labels = get_training_datasets() #获取数据
    lu.train(input_vecs,labels,10,0.01) #训练
    return lu #返回训练好的线性单元

if __name__=='__main__':
    linear_unit = train_linear_unit()
    print(linear_unit) #打印训练获得的权重
    print('Work 3.4 years, monthly salary = %.2f' % linear_unit.predict([3.4]))
    print('Work 15 years, monthly salary = %.2f' % linear_unit.predict([15]))
    print('Work 1.5 years, monthly salary = %.2f' % linear_unit.predict([1.5]))
    print('Work 6.3 years, monthly salary = %.2f' % linear_unit.predict([6.3]))
# Out:
# weights	:[1124.0634970262222]
# bias	:85.485289
#
# Work 3.4 years, monthly salary = 3907.30
# Work 15 years, monthly salary = 16946.44
# Work 1.5 years, monthly salary = 1771.58
# Work 6.3 years, monthly salary = 7167.09
